# %% [markdown]
# ## Data management on the cluster
#
# The way this works: data is stored in one place (our GCS bucket) and we pull it down from there and push it back there.
#
# As much as possible, avoid creating data locally on the machine that is running your notebook. This will help us:
#
# 1. Collaborate more readily -- everyone's code points to one place.
# 2. Work more rapidly -- worker nodes on the cluster get their own data.
# 3. Avoid losing data -- GCS is solid, but nodes are kinda ephemeral.
#
# In the following code, we're going to read and write data into GCS using

# %%
import h5py
import scipy.io as sio
import gcsfs

# %%
fs = gcsfs.GCSFileSystem(project='learning-2-learn-221016', token='browser')
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=586241054156-8986sjc0h0683jmpb150i0m8cucrttds.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.full_control&state=EDZhtNpeerAg6k7qVzRKCd0Opgaosg&prompt=consent&access_type=offline

# %%
fs.ls('/learning2learn/Buffalo/BuffaloLabTestSet/')
# Out:
# ['learning2learn/Buffalo/BuffaloLabTestSet/CSC84a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC45_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC107_ex/',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC67a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC84_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC48_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC74_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC68a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC78_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC66_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC46a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC77a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC33_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC38a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC60a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC72a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC95a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC124_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC22a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC101_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC111_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC93_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC105_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC110_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC14a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC29a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC77_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC36_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC38_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC121_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC39a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC58a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC46_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC96_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC65_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC1a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC44a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC49_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC57a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC5_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC35_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC41_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC42a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC6a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC81_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC75_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC7a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC4a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC73_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC19_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC27a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC80a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC91_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC92_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC106_ex/',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC20_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC13_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC2a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC117_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC27_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC17_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC56a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC64a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC118_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC36a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC4_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC49a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC62a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC103_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC1_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC122_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC48a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC74a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC108_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC10a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC33a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC37_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC104_ex/',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC29_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC34_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC58_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC57_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC30_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC67_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC31_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC7_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC32a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC61_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC105_ex/',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC52_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC55a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC3_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC51a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC24a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC100_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC15_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC39_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC120_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC21a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC123_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC10_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC104_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC112_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC106_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC18a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC115_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC42_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC56_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC107_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC30a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC16_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC26_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC66a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC72_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC54_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC86_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC94_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC82a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC50_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC88_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC101_ex/',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC70_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC25a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC68_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC94a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC108_ex/',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC34a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC52a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC89a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC87a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC62_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC75a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC16a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC88a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC85a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC61a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC19a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC91a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC92a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC47a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC20a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC12_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC60_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC25_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC11_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC21_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC9a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC53a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC79a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC90a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC69_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC37a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC50a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC86a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC12a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC69a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC22_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC24_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC28a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC116_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC15a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC51_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC81a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC89_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC93a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC40_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC109_ex/',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC76_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC17a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC119_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC11a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC79_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC65a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC64_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC23_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC40a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC8_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC114_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC100_ex/',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC83a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC102_ex/',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC103_ex/',
#  'learning2learn/Buffalo/BuffaloLabTestSet/SA181126.nex5',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC71_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC3a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC85_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC14_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC80_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC35a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC47_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC102_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC96a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC23a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC63a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC82_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC26a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC43a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC13a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC97_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC41a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC54a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC44_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC78a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC113_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC18_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC63_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC70a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC45a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC71a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC73a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC109_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC95_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC32_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC83_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC98_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC90_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC2_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC99_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC6_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC28_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC43_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC55_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC76a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC87_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC31a_ex.mat',
#  'learning2learn/Buffalo/BuffaloLabTestSet/',
#  'learning2learn/Buffalo/BuffaloLabTestSet/CSC53_ex.mat']

# %%
import gcsfs

from scipy.io import loadmat
import numpy as np

from dask import delayed
import dask.array as da

@delayed
def get_matfile(fname, project, keys):
    """ 
    Getsdata from a matfile
    
    """
    fs = gcsfs.GCSFileSystem(project=project)
    with fs.open(fname, 'rb') as f:
        mat = loadmat(f, squeeze_me=True)

    for k in keys:
        mat = mat[k]
    
    return mat.item()


def get_spkwv(fnames, project, shape=(100000, 33)):
    """ 
    Gets spike waveforms from data
    """
    data = []
    for fname in fnames:
        matfile = get_matfile(fname, project, ["dataToSave", "spkwv"])
        data.append(da.from_delayed(matfile, 
                                    shape=shape, 
                                    dtype=np.float64))
    return da.concatenate(data)

# %%
foo = get_spkwv(['learning2learn/Buffalo/BuffaloLabTestSet/CSC84a_ex.mat'], 'learning-2-learn-221016')

# %%
fs.

# %%
fs.put('/home/jovyan/dask-tutorial/data/random.hdf5', '/learning2learn/tutorial/random.hdf5')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /srv/conda/envs/notebook/lib/python3.6/site-packages/gcsfs/core.py in put(self, lpath, rpath, blocksize, acl, metadata, recursive)
#     991                             break
# --> 992                         f1.write(d)
#     993
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/gcsfs/core.py in write(self, data)
#    1378         if self.buffer.tell() >= self.blocksize:
# -> 1379             self.flush()
#    1380         return out
#
# </srv/conda/envs/notebook/lib/python3.6/site-packages/decorator.py:decorator-gen-158> in flush(self, force)
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/gcsfs/core.py in _tracemethod(f, self, *args, **kwargs)
#      51
# ---> 52     return f(self, *args, **kwargs)
#      53
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/gcsfs/core.py in flush(self, force)
#    1424                 # At initialize a multipart upload, setting self.location
# -> 1425                 self._initiate_upload()
#    1426
#
# </srv/conda/envs/notebook/lib/python3.6/site-packages/decorator.py:decorator-gen-160> in _initiate_upload(self)
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/gcsfs/core.py in _tracemethod(f, self, *args, **kwargs)
#      51
# ---> 52     return f(self, *args, **kwargs)
#      53
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/gcsfs/core.py in _initiate_upload(self)
#    1487                              uploadType='resumable',
# -> 1488                              json={'name': self.key, 'metadata': self.metadata})
#    1489         self.location = r.headers['Location']
#
# </srv/conda/envs/notebook/lib/python3.6/site-packages/decorator.py:decorator-gen-127> in _call(self, method, path, *args, **kwargs)
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/gcsfs/core.py in _tracemethod(f, self, *args, **kwargs)
#      51
# ---> 52     return f(self, *args, **kwargs)
#      53
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/gcsfs/core.py in _call(self, method, path, *args, **kwargs)
#     481                                          params=kwargs, json=json, headers=headers, data=data)
# --> 482                 validate_response(r, path)
#     483                 break
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/gcsfs/core.py in validate_response(r, path)
#     158         elif r.status_code == 403:
# --> 159             raise IOError("Forbidden: %s\n%s" % (path, msg))
#     160         elif r.status_code == 429:
#
# OSError: Forbidden: https://www.googleapis.com/upload/storage/v1/b/learning2learn/o
# Insufficient Permission
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-9-5c0cccae6ef6> in <module>
# ----> 1 fs.put('/home/jovyan/dask-tutorial/data/random.hdf5', '/learning2learn/tutorial/random.hdf5')
#
# </srv/conda/envs/notebook/lib/python3.6/site-packages/decorator.py:decorator-gen-146> in put(self, lpath, rpath, blocksize, acl, metadata, recursive)
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/gcsfs/core.py in _tracemethod(f, self, *args, **kwargs)
#      50         logger.log(logging.DEBUG - 1, tb_io.getvalue())
#      51
# ---> 52     return f(self, *args, **kwargs)
#      53
#      54
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/gcsfs/core.py in put(self, lpath, rpath, blocksize, acl, metadata, recursive)
#     990                         if not d:
#     991                             break
# --> 992                         f1.write(d)
#     993
#     994     def getxattr(self, path, attr):
#
# </srv/conda/envs/notebook/lib/python3.6/site-packages/decorator.py:decorator-gen-166> in __exit__(self, *args)
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/gcsfs/core.py in _tracemethod(f, self, *args, **kwargs)
#      50         logger.log(logging.DEBUG - 1, tb_io.getvalue())
#      51
# ---> 52     return f(self, *args, **kwargs)
#      53
#      54
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/gcsfs/core.py in __exit__(self, *args)
#    1623     @_tracemethod
#    1624     def __exit__(self, *args):
# -> 1625         self.close()
#    1626
#    1627
#
# </srv/conda/envs/notebook/lib/python3.6/site-packages/decorator.py:decorator-gen-163> in close(self)
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/gcsfs/core.py in _tracemethod(f, self, *args, **kwargs)
#      50         logger.log(logging.DEBUG - 1, tb_io.getvalue())
#      51
# ---> 52     return f(self, *args, **kwargs)
#      53
#      54
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/gcsfs/core.py in close(self)
#    1587         else:
#    1588             if not self.forced:
# -> 1589                 self.flush(force=True)
#    1590             else:
#    1591                 logger.debug("close with forced=True, bypassing final flush.")
#
# </srv/conda/envs/notebook/lib/python3.6/site-packages/decorator.py:decorator-gen-158> in flush(self, force)
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/gcsfs/core.py in _tracemethod(f, self, *args, **kwargs)
#      50         logger.log(logging.DEBUG - 1, tb_io.getvalue())
#      51
# ---> 52     return f(self, *args, **kwargs)
#      53
#      54
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/gcsfs/core.py in flush(self, force)
#    1423             else:
#    1424                 # At initialize a multipart upload, setting self.location
# -> 1425                 self._initiate_upload()
#    1426
#    1427         if self.location is not None:
#
# </srv/conda/envs/notebook/lib/python3.6/site-packages/decorator.py:decorator-gen-160> in _initiate_upload(self)
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/gcsfs/core.py in _tracemethod(f, self, *args, **kwargs)
#      50         logger.log(logging.DEBUG - 1, tb_io.getvalue())
#      51
# ---> 52     return f(self, *args, **kwargs)
#      53
#      54
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/gcsfs/core.py in _initiate_upload(self)
#    1486                                      '/v1/b/%s/o' % quote_plus(self.bucket),
#    1487                              uploadType='resumable',
# -> 1488                              json={'name': self.key, 'metadata': self.metadata})
#    1489         self.location = r.headers['Location']
#    1490
#
# </srv/conda/envs/notebook/lib/python3.6/site-packages/decorator.py:decorator-gen-127> in _call(self, method, path, *args, **kwargs)
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/gcsfs/core.py in _tracemethod(f, self, *args, **kwargs)
#      50         logger.log(logging.DEBUG - 1, tb_io.getvalue())
#      51
# ---> 52     return f(self, *args, **kwargs)
#      53
#      54
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/gcsfs/core.py in _call(self, method, path, *args, **kwargs)
#     480                 r = self.session.request(method, path,
#     481                                          params=kwargs, json=json, headers=headers, data=data)
# --> 482                 validate_response(r, path)
#     483                 break
#     484             except (HttpError, RequestException, RateLimitException, GoogleAuthError) as e:
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/gcsfs/core.py in validate_response(r, path)
#     157             raise FileNotFoundError(path)
#     158         elif r.status_code == 403:
# --> 159             raise IOError("Forbidden: %s\n%s" % (path, msg))
#     160         elif r.status_code == 429:
#     161             raise RateLimitException(error)
#
# OSError: Forbidden: https://www.googleapis.com/upload/storage/v1/b/learning2learn/o
# Insufficient Permission

# %%
with fs.open('learning2learn/Buffalo/BuffaloLabTestSet/CSC28_ex.mat', 'rb') as f:
    f = h5py.File(f,'r')
    spkwv = f["dataToSave"]["spkwv"][()]
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-8b95f05889c9> in <module>
#       1 with fs.open('learning2learn/Buffalo/BuffaloLabTestSet/CSC28_ex.mat', 'rb') as f:
# ----> 2     f = h5py.File(f,'r')
#       3     spkwv = f["dataToSave"]["spkwv"][()]
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     392                 fid = make_fid(name, mode, userblock_size,
#     393                                fapl, fcpl=make_fcpl(track_order=track_order),
# --> 394                                swmr=swmr)
#     395
#     396             if swmr_support:
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     168         if swmr and swmr_support:
#     169             flags |= h5f.ACC_SWMR_READ
# --> 170         fid = h5f.open(name, flags, fapl=fapl)
#     171     elif mode == 'r+':
#     172         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (file signature not found)
